# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelBinarizer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score, classification_report

# %%
# %%html
# <style>
#   table {margin-left: 0 !important;}
# </style>
# Out:
# <style>
#   table {margin-left: 0 !important;}
# </style>

# %% [markdown]
# # O Dataset
# ## German Credit Data
#
# Dataset com dados sobre clientes interessados em pedir créditos a um certo banco com intuíto de classificá-los em confiáveis ou não (Good/bad), para melhorar a tomada de decisão relacionada a empréstimos.
#
# Fonte: [UCI]( https://archive.ics.uci.edu/ml/datasets/Statlog+%28German+Credit+Data%29)
#
# - **Primeira coluna (Qualitativo):** Status da conta corrente existente.
#
# | Atributos 	| Descrição 		|
# | ------------- |-----------------------|
# | A11      	| < 0 DM 		|
# | A12      	| 0 <= ... < 200 DM     |
# | A13 		| ... >= 200 DM 	|
# | A14 		| Sem conta corrente 	|
#
#
# - **Segunda coluna (Numérico):** Duração no mês.
#
# - **Terceira coluna (Qualitativo):** Histórico de crédito.
#
# | Atributos 	| Descrição 		|
# | ------------- |-----------------------|
# | A30      	| nenhum crédito recebido ou todos os créditos já devolvidos devidamente. 		|
# | A31      	|  todos os créditos deste banco foram devolvidos devidamente     |
# | A32 		| créditos existentes devidamente pagos até agora 	|
# | A33 		| atraso no pagamento no passado 	|
# | A34 		| conta crítica / outros créditos existentes (não neste banco) 	|
#
# - **Quarta coluna (Qualitativo):** Propósito do crédito.
#
# | Atributos 	| Descrição 		|
# | ------------- |-----------------------|
# | A40      	| Carro novo 		|
# | A41      	| Carro usado   	|
# | A42 		| Móveis/Equipamentos 	|
# | A43 		| Rádio/Televisão 	|
# | A44 		| Eletrodomésticos 	|
# | A45 		| Reparos 		|
# | A46 		| Educação 		|
# | A47 		| Férias 		|
# | A48 		| Retraining[?] 	|
# | A49 		| Business 		|
# | A410 		| Others 		|
#
# - **Quinta coluna (Numérico):** Quantia de crédito.
#
# - **Sexta coluna (Qualitativo):** Conta de poupança / títulos.
#
# | Atributos 	| Descrição 			|
# | ------------- |-------------------------------|
# | A61      	| ... < 100 DM 			|
# | A62      	| 100 <= ... < 500 DM   	|
# | A63 		| 500 <= ... < 1000 DM 		|
# | A64 		| .. >= 1000 DM 		|
# | A65 		| desconhecido / sem poupança 	|
#
# - **Sétima coluna (Qualitativo):** Emprego atual desde..
#
# | Atributos 	| Descrição 			|
# | ------------- |-------------------------------|
# | A71      	| Desempregado 			|
# | A72      	| ... < 1 year   		|
# | A73 		| 1 <= ... < 4 years 		|
# | A74 		| 4 <= ... < 7 years 		|
# | A75 		| .. >= 7 years 		|
#
# - **Oitava coluna (Numérico):** Taxa de parcelamento em porcentagem da renda disponível.
#
# - **Nona coluna (Qualitativo):** Status pessoal e genero
#
# | Atributos 	| Descrição 			        |
# | ------------- |---------------------------------------|
# | A91      	| Masculino : divorciado/separado       |
# | A92      	| Feminino : divorciada/separada/casada |
# | A93 		| Masculino : solteiro  		|
# | A94 		| Masculino : casado/viúvo 		|
# | A95 		| Feminino : solteira                   |
#
# - **Décima coluna (Qualitativo):** Outros devedores
#
# | Atributos 	| Descrição     |
# | ------------- |---------------|
# | A101      	| Nenhum        |
# | A102      	| Co-requerente |
# | A103 		| Guarantor     |
#
# - **Décima primeira coluna (Numérico):** Residência atual desde...
#
# - **Décima segunda coluna (Qualitativo):** Propriedade
#
# | Atributos 	| Descrição      	    |
# | ------------- |---------------------------|
# | A121      	| Imobiliária    	    |
# | A122      	| Building society savings agreement[?] / seguro de vida |
# | A123 		| Carro ou outro 	    |
# | A124 		| Desconhecido / Não possui |
#
# - **Décima terceira coluna (Numérico):** Idade em anos
#
# - **Décima quarta coluna (Qualitativo):** Outros planos de parcelamento
#
# | Atributos 	| Descrição |
# | ------------- |-----------|
# | A141      	| Banco     |
# | A142      	| Loja      |
# | A143 		| Nenhum    |
#
# - **Décima quinta coluna (Qualitativo):** Habitação
#
# | Atributos 	| Descrição    |
# | ------------- |--------------|
# | A151      	| Aluguel      |
# | A152      	| Casa própria |
# | A153 		| De graça     |
#
# - **Décima sexta coluna (Numérico):** Número de créditos existentes neste banco.
#
# - **Décima sétima coluna (Qualitativo):** Trabalho
#
# | Atributos 	| Descrição  					  |
# | ------------- |-------------------------------------------------|
# | A171      	| Desempregado / sem qualificação - não residente |
# | A172      	| Sem qualificação - residente 			  |
# | A173 		| Funcionário qualificado / Funcionário           |
# | A174      	| Gerente / Autônomo / Funcionário / Funcionário altamente qualificado      |
#
# - **Décima oitava coluna (Numérico):** Number of people being liable to provide maintenance for[?]
#
# - **Décima nona coluna (Qualitativo):** Telefone
#
# | Atributos 	| Descrição  	       		         |
# | ------------- |----------------------------------------|
# | A191      	| Nenhum 				 |
# | A192      	| sim, registrado com o nome de clientes |
#
#
# - **Vigésima coluna (Qualitativo):** Trabalhador estrangeiro
#
# | Atributos 	| Descrição |
# | ------------- |-----------|
# | A201      	| Yes       |
# | A202      	| No        |

# %% [markdown]
# ### Lendo o dataset

# %%
df = pd.read_csv('dataset.csv',sep=';')
df.head(10)
# Out:
#   status_conta  duracao_mes hist_credito proposito_cred  quantia_credito  \
# 0          A11            6          A34            A43             1169
# 1          A12           48          A32            A43             5951
# 2          A14           12          A34            A46             2096
# 3          A11           42          A32            A42             7882
# 4          A11           24          A33            A40             4870
# 5          A14           36          A32            A46             9055
# 6          A14           24          A32            A42             2835
# 7          A12           36          A32            A41             6948
# 8          A14           12          A32            A43             3059
# 9          A12           30          A34            A40             5234
#
#   conta emprego_atual_desde  porc_taxa_parcelamento status_genero  \
# 0   A65                 A75                       4           A93
# ...

# %% [markdown]
# # Análise Exploratória de Dados
#
# Assim como visto durante o semestre, o primeiro passo a ser dado em um projeto de aprendizado de máquina é a análise exploratória de dados, momento no qual começamos a ter uma noção do que estamos lidando e quais tipos de dados teremos dentro do dataset.
#
# Como mostrado a baixo, temos as seguintes quantidades de colunas:
#
# | Categoricas   | Numericas     |
# | ------------- | ------------- |
# | 13            | 7             |

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   status_conta                1000 non-null   object
#  1   duracao_mes                 1000 non-null   int64
#  2   hist_credito                1000 non-null   object
#  3   proposito_cred              1000 non-null   object
#  4   quantia_credito             1000 non-null   int64
#  5   conta                       1000 non-null   object
#  6   emprego_atual_desde         1000 non-null   object
#  7   porc_taxa_parcelamento      1000 non-null   int64
#  8   status_genero               1000 non-null   object
#  9   outros_devedores            1000 non-null   object
#  10  resid_atual_desde           1000 non-null   int64
#  11  propriedade                 1000 non-null   object
#  12  idade                       1000 non-null   int64
# ...

# %% [markdown]
# Como é possível observar, o dataset não possui dados faltantes.

# %% [markdown]
# # Analisando possiveis correções
#
# Por meio de uma simples olhada nas correlações entre as colunas númericas, é possível ver que a correlação mais forte ocorre entre *quantia_credito* e *duracao_mes* e mesmo assim não é uma correlação forte, expressando apenas 0.624984.
# Analisando com mais calma, faz sentido essa relação: já que a quantia de crédito depende de quantos meses será previsto o empréstimo

# %%
df.corr()
# Out:
#                           duracao_mes  quantia_credito  \
# duracao_mes                  1.000000         0.624984
# quantia_credito              0.624984         1.000000
# porc_taxa_parcelamento       0.080873        -0.264304
# resid_atual_desde            0.033797         0.025907
# idade                       -0.034179         0.036604
# num_creditos_banco          -0.011284         0.020795
# num_pessoas_relacionadas    -0.023834         0.017142
# confiavel                    0.210222         0.143155
#
#                           porc_taxa_parcelamento  resid_atual_desde     idade  \
# duracao_mes                             0.080873           0.033797 -0.034179
# quantia_credito                        -0.264304           0.025907  0.036604
# porc_taxa_parcelamento                  1.000000           0.046419  0.055577
# resid_atual_desde                       0.046419           1.000000  0.264935
# ...

# %% [markdown]
# # Plotando gráficos
#
# Com a ferramenta dos gráficos, podemos analisar os dados de maneira geométrica e inferir algumas informações sobre as colunas, por exemplo:
# - Confiável: Podemos ver que a quantidade de clientes que podem cometer uma possível fraude é visívelmente menor daqueles que não tem a possibilidade;
# - Uma boa parte dos empréstimos tendem a durar 2 anos, enquanto que poucos duram mais do que 3 ou 4 anos;
# - A maioria dos clientes tendem a ter entre os 25 e 35 anos de idade;
# - Por fim, a quantia de crédito tende a ser pequena, com menos de 100 empréstimos passando do valor de 5000;

# %%
df.hist(figsize=(20,15))
plt.show()

# %% [markdown]
# # Descrevendo as colunas
#
# De maneira mais precisa, podemos confirmar o que inferimos dos gráficos através de uma analise mais precisa sobre algumas operações matemáticas nas colunas. Por exemplo:
#
# - Idade: podemos confirmar que a idade média dos clientes que pedem empréstimo fica por volta dos 35 anos, com um desvio padrão de mais ou menos 11 anos;
# - Duracao_mes: os empréstimos tendem a durar quase dois anos;
# - A quantia de crédito tem uma média de 3000, não passando dos 5000;

# %%
df.describe()
# Out:
#        duracao_mes  quantia_credito  porc_taxa_parcelamento  \
# count  1000.000000      1000.000000              1000.00000
# mean     20.903000      3271.258000                 2.97600
# std      12.058814      2822.736876                 1.11744
# min       4.000000       250.000000                 1.00000
# 25%      12.000000      1365.500000                 2.00000
# 50%      18.000000      2319.500000                 3.00000
# 75%      24.000000      3972.250000                 4.00000
# max      72.000000     18424.000000                 4.00000
#
#        resid_atual_desde        idade  num_creditos_banco  \
# count        1000.000000  1000.000000         1000.000000
# mean            2.844000    35.556000            1.407000
# std             1.104937    11.368822            0.577654
# min             1.000000    19.000000            1.000000
# 25%             2.000000    27.000000            1.000000
# 50%             3.000000    33.000000            1.000000
# ...

# %% [markdown]
# # Separando as bases de treino e teste
#
# Como aprendido durante o semestre, antes de inciarmos o pré-processamento iremos dividir a base em duas partes:
# - Treino: base para treinar o modelo, aprimorá-lo e fazer ajustes
# - Teste: base para aplicação do modelo, para testar seu potencial de previsão
#
# Abaixo, definimos 4 arrays
# - x_treino = contém os atributos preditivos do dataset para treino
# - y_treino = contém a coluna alvo do dataset para a base de treino
# - x_teste  = contém os atributos preditivos do dataset para o teste
# - y_teste  = contém a coluna alvo do dataset para a base de teste

# %%
x_treino, x_teste, y_treino, y_teste = train_test_split(df.drop('confiavel', axis=1), df.confiavel, test_size = 0.3, random_state=42)

# %% [markdown]
# # Pré-processamento
#
# Após separarmos as bases de treino e teste, separamos as colunas númericas das categóricas para aplicar a normalização dos dados

# %%
num_cols   = [column for column in x_treino.columns if x_treino[column].dtype == 'int64']
cat_cols = [column for column in x_treino.columns if x_treino[column].dtype == object] 
print()
print('Colunas numéricas: ')
print(num_cols)
print()
print('Colunas categóricas: ')
print(cat_cols)
# Out:
# Colunas numéricas:
# ['duracao_mes', 'quantia_credito', 'porc_taxa_parcelamento', 'resid_atual_desde', 'idade', 'num_creditos_banco', 'num_pessoas_relacionadas']
#
# Colunas categóricas:
# ['status_conta', 'hist_credito', 'proposito_cred', 'conta', 'emprego_atual_desde', 'status_genero', 'outros_devedores', 'propriedade', 'outros_planos_parcelamento', 'tipo_habitacao', 'trabalho', 'possui_telefone', 'trabalhador_estrangeiro']

# %% [markdown]
# Após a separação dos diferentes tipos de dados das colunas, aplicaremos o pipeline para ambos os vetores e então o pré-processamento em cada um deles como programado abaixo. Para as colunas númericas aplicamos a padronização das escalas com o uso do StandardScaler, enquanto que para as colunas categóricas aplicamos o OneHot encoding. Por fim, aplicamos os pipelines nos vetores e armazenamos todas as colunas pré-processadas em outro vetor, preprocess.

# %%
num_preprocess = Pipeline([('scaler', StandardScaler())])
cat_preprocess = Pipeline([('one_hot', OneHotEncoder())])
preprocess = ColumnTransformer([('numerical', num_preprocess, num_cols), ('categorical', cat_preprocess, cat_cols)])

# %% [markdown]
# # Modelos
#
# Aqui, para automatizar o treinamento, criamos uma função que o retorno executa o pré-processamento e logo após cria um modelo passado por parâmetro.
# Os modelos escolhidos foram a Árvore de Decisão e a Regressão Logística, a Regressão Linear não foi experimentada pois não pode ser utilizada quando a coluna alvo é categórica.

# %%
def create_model(model, prep = None):
    if preprocess:
        return Pipeline([('preprocess',prep), ('model',model)])
    else:
        return model

# %%
decision_tree = create_model(DecisionTreeClassifier(), preprocess)
log_reg = create_model(LogisticRegression(), preprocess)

# %% [markdown]
# # Treinamento
#
# Abaixo, chamamos o método fit para treinar os dois modelos escolhidos.

# %%
decision_tree.fit(x_treino,y_treino)
log_reg.fit(x_treino,y_treino)
# Out:
# Pipeline(memory=None,
#          steps=[('preprocess',
#                  ColumnTransformer(n_jobs=None, remainder='drop',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('numerical',
#                                                   Pipeline(memory=None,
#                                                            steps=[('scaler',
#                                                                    StandardScaler(copy=True,
#                                                                                   with_mean=True,
#                                                                                   with_std=True))],
#                                                            verbose=False),
#                                                   ['duracao_mes',
#                                                    'quantia_credito',
# ...

# %% [markdown]
# # Avaliação de Desempenho

# %% [markdown]
# ## Árvore de Decisão

# %%
tree_prediction = decision_tree.predict(x_teste)

print('Matriz de Confusão: ')
print(confusion_matrix(y_teste, tree_prediction))
print()

print(' Acc: {}\n Precision: {}\n Recall: {}\n F1: {}'
      .format(accuracy_score(y_teste, tree_prediction), precision_score(y_teste, tree_prediction), recall_score(y_teste, tree_prediction), f1_score(y_teste, tree_prediction)))

tn, fp, fn, tp = confusion_matrix(y_teste, tree_prediction).ravel()
sns.heatmap([[tn,fp],[fn,tp]], annot=True)
plt.show()
# Out:
# Matriz de Confusão:
# [[159  50]
#  [ 43  48]]
#
#  Acc: 0.69
#  Precision: 0.7871287128712872
#  Recall: 0.7607655502392344
#  F1: 0.7737226277372261

# %% [markdown]
# ## Regressão Logística

# %%
log_reg_prediction = log_reg.predict(x_teste)

print('Matriz de Confusão')
print(confusion_matrix(y_teste, log_reg_prediction))
print()

print(' Acc: {}\n Precision: {}\n Recall: {}\n F1: {}'
      .format(accuracy_score(y_teste, log_reg_prediction), precision_score(y_teste, log_reg_prediction), recall_score(y_teste, log_reg_prediction), f1_score(y_teste, log_reg_prediction)))

tn, fp, fn, tp = confusion_matrix(y_teste, log_reg_prediction).ravel()
sns.heatmap([[tn,fp],[fn,tp]], annot=True)
plt.show()
# Out:
# Matriz de Confusão
# [[189  20]
#  [ 46  45]]
#
#  Acc: 0.78
#  Precision: 0.8042553191489362
#  Recall: 0.9043062200956937
#  F1: 0.8513513513513514

# %% [markdown]
# # Relatório de Classificação

# %% [markdown]
# ## Árvore de Decisão

# %%
print(classification_report(y_teste, tree_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.79      0.76      0.77       209
#            2       0.49      0.53      0.51        91
#
#     accuracy                           0.69       300
#    macro avg       0.64      0.64      0.64       300
# weighted avg       0.70      0.69      0.69       300

# %% [markdown]
# ## Regressão Logística

# %%
print(classification_report(y_teste, log_reg_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.80      0.90      0.85       209
#            2       0.69      0.49      0.58        91
#
#     accuracy                           0.78       300
#    macro avg       0.75      0.70      0.71       300
# weighted avg       0.77      0.78      0.77       300

# %% [markdown]
# # Modelo escolhido

# %% [markdown]
# Devido ao melhor desempenho nos testes, o modelo escolhido foi a Regressão Logística.
